# %%
#Load_Data_Files
from langchain_community.document_loaders import TextLoader
loader = TextLoader("Research on firewall technology and.txt")
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'Research on firewall technology and.txt'}, page_content='')]

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4
loader = WebBaseLoader(web_path=('https://www.fortinet.com/resources/cyberglossary/firewall',), 
                       bs_kwargs=dict(parse_only=bs4.SoupStrainer(class_=('page--body'))))

web_document = loader.load()
web_document
# Out:
# [Document(metadata={'source': 'https://www.fortinet.com/resources/cyberglossary/firewall'}, page_content="\n\n\n\n\n\n\n\n\nWhat Is a Firewall?\nA guide to firewalls, types of firewalls, and what to look for in a firewall solution.\n\n            Benefits of Fortinet Data Center Firewalls\n        \n\n            Speak with an Expert\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFirewall Definition\n\n\nHybrid Mesh Firewall\n\n\nFirewall Solutions\n\n\nHow Fortinet Can Help\n\n\n\nFAQs\n\n\n\n\nFirewall Definition\n\n\n\n\n Firewall Definition\n Hybrid Mesh Firewall\n Firewall Solutions\n How Fortinet Can Help\n FAQs\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \n    \n        Firewall Definition: What Is a Network Firewall?\n    \n\n\n    \n\n\n    \n\n\n\n\nA firewall is a network security device designed to monitor, filter, and control incoming and outgoing network traffic based on predetermined secur
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('3438872.3439090.pdf')
docs = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
document = text_splitter.split_documents(docs)
document[:5]
# Out:
# [Document(metadata={'source': '3438872.3439090.pdf', 'page': 0}, page_content='255\nResearch on intelligent Firewall for network security\n \n \nWang Daxian \n Department of Computer \n Anhui Sanlian University \n Hefei China \n 472403608@qq.com \nZhang Jishan \n Department of Computer  \nAnhui Sanlian University \n Hefei China \n 695856623@qq.com \nYu jiujiu \nDepartment of Computer \n Anhui Sanlian University \n Hefei China \n 1072041679@qq.com \n\xa0\nABSTRACT \nBecause of poor ability in network security market, the firewal l \nlack of intelligent response to network attacks. Using intellig ent \nfirewall , the firewall can reduce the workload of firewall \nmaintenance through intelligent and automatic policy response. \nThe experiment shows that this intelligent mode enhance the \ndefense ability of firewall and also meet the demand. \nCCS CONCEPTS \n  Security and privacy \n\uf0b7  \uf0b7  ~Security in hardware \n\uf0b7  \uf0b7  ~Embedded systems security \nKEYWORDS \n\xa0\nfir
# ...

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

db = Chroma.from_documents(document, OllamaEmbeddings())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 from langchain_community.embeddings import OllamaEmbeddings
#       2 from langchain_community.vectorstores import Chroma
# ----> 4 db = Chroma.from_documents(document, OllamaEmbeddings())
#
# File c:\Engineering at NSUT\LangChain\myenv\lib\site-packages\langchain_community\vectorstores\chroma.py:878, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     876 texts = [doc.page_content for doc in documents]
#     877 metadatas = [doc.metadata for doc in documents]
# --> 878 return cls.from_texts(
#     879     texts=texts,
#     880     embedding=embedding,
#     881     metadatas=metadatas,
#     882     ids=ids,
#     883     collection_name=collection_name,
# ...

# %%
query = ''
result = db.similarity_search(query)
result.page_content
